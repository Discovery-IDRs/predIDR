# %%
# increase batch size to 128

import os
from math import floor

import Bio.SeqIO as SeqIO
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import load_model

import sys  
sys.path.append('../../../src')
from metrics import *

from pandas.core.common import flatten

# %%
model_name = "jason_cnn_3_2"

# %%
class BatchGenerator(keras.utils.Sequence):
    """Label, batch, and pad protein sequence data.

    Only complete batches are returned, so a single epoch may not train on every example."""
    def __init__(self, records, batch_size, sym_codes, shuffle=True):
        self.records = records
        self.indices = np.arange(len(self.records))
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.ctable = {}  # Category table
        for i, sym_code in enumerate(sym_codes):
            self.ctable[sym_code] = i
        self.on_epoch_end()

    def __len__(self):
        """Return number of batches."""
        return floor(len(self.records) / self.batch_size)

    def __getitem__(self, index):
        """Generate one batch of data."""
        indices = self.indices[index*self.batch_size:(index+1)*self.batch_size]
        records = [self.records[i] for i in indices]
        max_len = max([len(record[0]) for record in records])
        x = np.zeros((self.batch_size, max_len))
        y = np.zeros((self.batch_size, max_len))
        for i, (syms, labels) in enumerate(records):
            x[i, :len(syms)] = [self.ctable.get(sym, 0) for sym in syms]
            y[i, :len(syms)] = [int(label) for label in labels]

        x = keras.utils.to_categorical(x, num_classes=len(self.ctable))
        y = keras.utils.to_categorical(y, num_classes=2)
        for i, (syms, _) in enumerate(records):
            x[i, len(syms):, :] = 0
            y[i, len(syms):, :] = 0
        return x, y

    def on_epoch_end(self):
        """Shuffles data after each epoch."""
        if self.shuffle:
            np.random.shuffle(self.indices)

def load_data(seqs_path, labels_path):
    # Load files
    seqs = {}
    for record in SeqIO.parse(seqs_path, 'fasta'):
        accession = record.description.split('|')[0]
        seq = str(record.seq)
        seqs[accession] = seq
    labels = {}
    for record in SeqIO.parse(labels_path, 'fasta'):
        accession = record.description.split('|')[0]
        label = str(record.seq)
        labels[accession] = label

    # Bundle seqs and labels into single object
    records = []
    for accession, seq in seqs.items():
        records.append((seq, labels[accession]))

    return records

def decode_sym(batch, sym_codes):
    """Decodes residue symbols in batch of proteins from encoded form."""
    ctable, i = {}, 0
    for sym_code in sym_codes:
        ctable[i] = sym_code
        i += 1
        
    decoded_sym = []
    for protein in batch:
        decoded_protein = []
        for residue in protein:
            if sum(residue) == 0:
                pass
            else:
                decoded_residue = ctable[np.argmax(residue)]
                decoded_protein.append(decoded_residue)
        decoded_sym.append("".join(decoded_protein))
                           
    return decoded_sym

def decode_label_by_protein(batch_to_be_decoded, original_batch):
    """
    Decodes residue labels in batch of proteins from encoded form.
    Outputs list of str where each str is labels of one protein.
    
    batch_to_be_decoded:
    batch of labels which want to be decoded
    
    original_batch:
    original batch of labels generated by BatchGenerator which
    batch_to_be_decoded is derived from (this is needed in order
    to remove unwanted masked values)
    """
    decoded_labels = []
    for x in np.arange(len(original_batch)):
        protein = original_batch[x]
        decoded_protein = []
        for y in np.arange(len(protein)):
            residue = protein[y]
            if sum(residue) == 0:
                pass
            else:
                decoded_residue = np.argmax(batch_to_be_decoded[x][y])
                decoded_protein.append(str(decoded_residue))
        decoded_labels.append("".join(decoded_protein))
    return decoded_labels

def decode_label_to_lst(batch_to_be_decoded, original_batch):
    """
    Decodes residue labels in batch of proteins from encoded form.
    Outputs list of int where each int is label for one residue.
    
    batch_to_be_decoded:
    batch of labels which want to be decoded
    
    original_batch:
    original batch of labels generated by BatchGenerator which
    batch_to_be_decoded is derived from (this is needed in order
    to remove unwanted masked values)
    """
    decoded_labels = []
    for x in np.arange(len(original_batch)):
        protein = original_batch[x]
        for y in np.arange(len(protein)):
            residue = protein[y]
            if sum(residue) == 0:
                pass
            else:
                decoded_residue = np.argmax(batch_to_be_decoded[x][y])
                decoded_labels.append(decoded_residue)
    return decoded_labels
                           
class MaskedConv1D(keras.layers.Conv1D):
    def __init__(self, filters, kernel_size, **kwargs):
        super().__init__(filters, kernel_size, **kwargs)
        self.supports_masking = True

# %%
# Parameters
sym_codes = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L',
             'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']

# %%
# Load data
train_records = load_data('../../mobidb_validation/split_data/out/train_as_fasta.fasta', '../../mobidb_validation/split_data/out/train_labels_as_fasta.fasta')
validation_records = load_data('../../mobidb_validation/split_data/out/val_as_fasta.fasta', '../../mobidb_validation/split_data/out/val_labels_as_fasta.fasta')
test_records = load_data('../../mobidb_validation/split_data/out/test_as_fasta.fasta', '../../mobidb_validation/split_data/out/test_labels_as_fasta.fasta')

# %%
# Batch data
train_batches = BatchGenerator(train_records, 128, sym_codes)
validation_batches = BatchGenerator(validation_records, 32, sym_codes)
test_batches = BatchGenerator(test_records, 32, sym_codes)

# %%
# Build model
inputs = keras.layers.Input(shape=(None, 20), name='input1')
x = layers.Masking(mask_value=0, name='mask1')(inputs)
x = MaskedConv1D(128, 20, padding='same', activation='relu', name='conv1d1')(x)
x = MaskedConv1D(128, 20, padding='same', activation='relu', name='conv1d2')(x)
outputs = layers.Dense(2, activation='softmax', name='dense1')(x)

model = keras.Model(inputs=inputs, outputs=outputs, name=model_name)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
model.summary()
# Out:
# Model: "jason_cnn_3_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input1 (InputLayer)          [(None, None, 20)]        0
# _________________________________________________________________
# mask1 (Masking)              (None, None, 20)          0
# _________________________________________________________________
# conv1d1 (MaskedConv1D)       (None, None, 128)         51328
# _________________________________________________________________
# conv1d2 (MaskedConv1D)       (None, None, 128)         327808
# _________________________________________________________________
# dense1 (Dense)               (None, None, 2)           258
# =================================================================
# Total params: 379,394
# Trainable params: 379,394
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model
# Epochs are written explicitly in a training loop since Keras
# does not support generators for calculating validation metrics

num_epochs = 50

histories = []

metrics_df = pd.DataFrame()

for i in range(num_epochs):
    # Fit
    print(f'EPOCH {i}')
    history = model.fit(train_batches, epochs=1)
    histories.append(history)

    # Evaluate
    true_labels = []
    pred_labels = []
    for batch in validation_batches:
        true_labels.append(decode_label_to_lst(batch[1], batch[1]))
        pred_labels.append(decode_label_to_lst(model.predict(batch[0]), batch[1]))
    true_labels = list(flatten(true_labels))
    pred_labels = list(flatten(pred_labels))
    
    batch_metrics_df = get_binary_metrics(true_labels, pred_labels)
    print("Label Accuracy:", batch_metrics_df.loc[0].at["Accuracy"])
    
    metrics_df = metrics_df.append(batch_metrics_df, ignore_index = True)
# Out:
# EPOCH 0
# 135/135 [==============================] - 794s 6s/step - loss: 0.0341 - binary_accuracy: 0.9375
# Label Accuracy: 0.9309876094421928
# EPOCH 1
# 135/135 [==============================] - 768s 6s/step - loss: 0.0327 - binary_accuracy: 0.9385
# Label Accuracy: 0.9309876094421928
# EPOCH 2
# 135/135 [==============================] - 940s 7s/step - loss: 0.0317 - binary_accuracy: 0.9386
# Label Accuracy: 0.9309876094421928
# EPOCH 3
# 135/135 [==============================] - 1063s 8s/step - loss: 0.0314 - binary_accuracy: 0.9383
# Label Accuracy: 0.9309876094421928
# EPOCH 4
# 135/135 [==============================] - 836s 6s/step - loss: 0.0309 - binary_accuracy: 0.9383
# Label Accuracy: 0.9309876094421928
# EPOCH 5
# 135/135 [==============================] - 797s 6s/step - loss: 0.0312 - binary_accuracy: 0.9384
# Label Accuracy: 0.9309876094421928
# EPOCH 6
# 135/135 [==============================] - 805s 6s/step - loss: 0.0303 - binary_accuracy: 0.9385
# Label Accuracy: 0.9309702069733626
# EPOCH 7
# 135/135 [==============================] - 784s 6s/step - loss: 0.0313 - binary_accuracy: 0.9385
# Label Accuracy: 0.9309876094421928
# EPOCH 8
# 135/135 [==============================] - 775s 6s/step - loss: 0.0302 - binary_accuracy: 0.9385
# Label Accuracy: 0.9309392692509978
# EPOCH 9
# 135/135 [==============================] - 775s 6s/step - loss: 0.0300 - binary_accuracy: 0.9385
# Label Accuracy: 0.9308793274139158
# EPOCH 10
# 135/135 [==============================] - 782s 6s/step - loss: 0.0299 - binary_accuracy: 0.9386
# Label Accuracy: 0.930847422887727
# EPOCH 11
# 135/135 [==============================] - 774s 6s/step - loss: 0.0296 - binary_accuracy: 0.9385
# Label Accuracy: 0.9306047551279275
# EPOCH 12
# 135/135 [==============================] - 770s 6s/step - loss: 0.0293 - binary_accuracy: 0.9388
# Label Accuracy: 0.930530311233487
# EPOCH 13
# 135/135 [==============================] - 759s 6s/step - loss: 0.0299 - binary_accuracy: 0.9387
# Label Accuracy: 0.9308251863997773
# EPOCH 14
# 135/135 [==============================] - 797s 6s/step - loss: 0.0279 - binary_accuracy: 0.9386
# Label Accuracy: 0.929181619899143
# EPOCH 15
# 135/135 [==============================] - 772s 6s/step - loss: 0.0281 - binary_accuracy: 0.9390
# Label Accuracy: 0.9302286684404294
# EPOCH 16
# 135/135 [==============================] - 790s 6s/step - loss: 0.0277 - binary_accuracy: 0.9392
# Label Accuracy: 0.9303340500572348
# EPOCH 17
# 135/135 [==============================] - 760s 6s/step - loss: 0.0285 - binary_accuracy: 0.9392
# Label Accuracy: 0.9298284116573338
# EPOCH 18
# 135/135 [==============================] - 780s 6s/step - loss: 0.0275 - binary_accuracy: 0.9397
# Label Accuracy: 0.9286218404851034
# EPOCH 19
# 135/135 [==============================] - 781s 6s/step - loss: 0.0269 - binary_accuracy: 0.9399
# Label Accuracy: 0.9296456857346163
# EPOCH 20
# 135/135 [==============================] - 768s 6s/step - loss: 0.0271 - binary_accuracy: 0.9398
# Label Accuracy: 0.9259234910125916
# EPOCH 21
# 135/135 [==============================] - 786s 6s/step - loss: 0.0256 - binary_accuracy: 0.9406
# Label Accuracy: 0.9276830739720942
# EPOCH 22
# 135/135 [==============================] - 783s 6s/step - loss: 0.0251 - binary_accuracy: 0.9417
# Label Accuracy: 0.9277971568233147
# EPOCH 23
# 135/135 [==============================] - 773s 6s/step - loss: 0.0255 - binary_accuracy: 0.9421
# Label Accuracy: 0.9274800451690747
# EPOCH 24
# 135/135 [==============================] - 774s 6s/step - loss: 0.0250 - binary_accuracy: 0.9428
# Label Accuracy: 0.9299966355226928
# EPOCH 25
# 135/135 [==============================] - 790s 6s/step - loss: 0.0244 - binary_accuracy: 0.9431
# Label Accuracy: 0.9244539492002599
# EPOCH 26
# 135/135 [==============================] - 788s 6s/step - loss: 0.0233 - binary_accuracy: 0.9448
# Label Accuracy: 0.9171623147603873
# EPOCH 27
# 135/135 [==============================] - 788s 6s/step - loss: 0.0230 - binary_accuracy: 0.9452
# Label Accuracy: 0.9051207731336819
# EPOCH 28
# 135/135 [==============================] - 827s 6s/step - loss: 0.0230 - binary_accuracy: 0.9440
# Label Accuracy: 0.9270343486062556
# EPOCH 29
# 135/135 [==============================] - 766s 6s/step - loss: 0.0233 - binary_accuracy: 0.9467
# Label Accuracy: 0.9124539801379823
# EPOCH 30
# 135/135 [==============================] - 803s 6s/step - loss: 0.0221 - binary_accuracy: 0.9472
# Label Accuracy: 0.9079834792562571
# EPOCH 31
# 135/135 [==============================] - 802s 6s/step - loss: 0.0219 - binary_accuracy: 0.9476
# Label Accuracy: 0.9220408068557993
# EPOCH 32
# 135/135 [==============================] - 807s 6s/step - loss: 0.0208 - binary_accuracy: 0.9490
# Label Accuracy: 0.916610269776939
# EPOCH 33
# 135/135 [==============================] - 800s 6s/step - loss: 0.0222 - binary_accuracy: 0.9480
# Label Accuracy: 0.9228335859913993
# EPOCH 34
# 135/135 [==============================] - 799s 6s/step - loss: 0.0211 - binary_accuracy: 0.9496
# Label Accuracy: 0.9213698450020109
# EPOCH 35
# 135/135 [==============================] - 803s 6s/step - loss: 0.0211 - binary_accuracy: 0.9497
# Label Accuracy: 0.9284207452897317
# EPOCH 36
# 135/135 [==============================] - 806s 6s/step - loss: 0.0202 - binary_accuracy: 0.9511
# Label Accuracy: 0.9237046762367355
# EPOCH 37
# 135/135 [==============================] - 810s 6s/step - loss: 0.0199 - binary_accuracy: 0.9516
# Label Accuracy: 0.9138771153667667
# EPOCH 38
# 135/135 [==============================] - 810s 6s/step - loss: 0.0205 - binary_accuracy: 0.9510
# Label Accuracy: 0.9200723942703338
# EPOCH 39
# 135/135 [==============================] - 809s 6s/step - loss: 0.0195 - binary_accuracy: 0.9531
# Label Accuracy: 0.9107446709773227
# EPOCH 40
# 135/135 [==============================] - 794s 6s/step - loss: 0.0201 - binary_accuracy: 0.9514
# Label Accuracy: 0.9265625483401912
# EPOCH 41
# 135/135 [==============================] - 820s 6s/step - loss: 0.0191 - binary_accuracy: 0.9531
# Label Accuracy: 0.8986373866905918
# EPOCH 42
# 135/135 [==============================] - 805s 6s/step - loss: 0.0191 - binary_accuracy: 0.9541
# Label Accuracy: 0.9195735234972001
# EPOCH 43
# 135/135 [==============================] - 810s 6s/step - loss: 0.0185 - binary_accuracy: 0.9546
# Label Accuracy: 0.9115896575194135
# EPOCH 44
# 135/135 [==============================] - 804s 6s/step - loss: 0.0182 - binary_accuracy: 0.9552
# Label Accuracy: 0.9160533907743712
# EPOCH 45
# 135/135 [==============================] - 799s 6s/step - loss: 0.0191 - binary_accuracy: 0.9540
# Label Accuracy: 0.9126173699842217
# EPOCH 46
# 135/135 [==============================] - 796s 6s/step - loss: 0.0179 - binary_accuracy: 0.9563
# Label Accuracy: 0.9040379528509112
# EPOCH 47
# 135/135 [==============================] - 791s 6s/step - loss: 0.0190 - binary_accuracy: 0.9544
# Label Accuracy: 0.9197920211614021
# EPOCH 48
# 135/135 [==============================] - 820s 6s/step - loss: 0.0179 - binary_accuracy: 0.9552
# Label Accuracy: 0.9255416035021502
# EPOCH 49
# 135/135 [==============================] - 806s 6s/step - loss: 0.0188 - binary_accuracy: 0.9538
# Label Accuracy: 0.9136218791572565

# %%
metrics_df
# Out:
#     Accuracy       MCC  Sensitivity  Specificity  Precision        F1
# 0   0.930988  0.000000     0.000000     1.000000   0.000000  0.000000
# 1   0.930988  0.000000     0.000000     1.000000   0.000000  0.000000
# 2   0.930988  0.000000     0.000000     1.000000   0.000000  0.000000
# 3   0.930988  0.000000     0.000000     1.000000   0.000000  0.000000
# 4   0.930988  0.000000     0.000000     1.000000   0.000000  0.000000
# 5   0.930988  0.000000     0.000000     1.000000   0.000000  0.000000
# 6   0.930970  0.009285     0.000336     0.999956   0.363636  0.000672
# 7   0.930988  0.000000     0.000000     1.000000   0.000000  0.000000
# 8   0.930939  0.010976     0.000588     0.999904   0.313433  0.001175
# 9   0.930879  0.016279     0.001303     0.999787   0.312081  0.002595
# 10  0.930847  0.001347     0.000238     0.999832   0.094972  0.000475
# 11  0.930605  0.060932     0.012258     0.998680   0.407735  0.023800
# 12  0.930530  0.072261     0.016685     0.998272   0.417163  0.032086
# 13  0.930825  0.013158     0.001205     0.999736   0.252941  0.002398
# 14  0.929182  0.095016     0.034953     0.995469   0.363809  0.063778
# 15  0.930229  0.085515     0.024138     0.997396   0.407232  0.045574
# 16  0.930334  0.082824     0.022261     0.997648   0.412299  0.042240
# 17  0.929828  0.081212     0.024670     0.996926   0.373014  0.046279
# 18  0.928622  0.109275     0.046034     0.994046   0.364342  0.081740
# 19  0.929646  0.084197     0.027052     0.996553   0.367810  0.050397
# 20  0.925923  0.110012     0.059539     0.990147   0.309361  0.099859
# 21  0.927683  0.102790     0.046945     0.992971   0.331126  0.082231
# 22  0.927797  0.102370     0.046146     0.993152   0.333131  0.081063
# 23  0.927480  0.089848     0.040388     0.993239   0.306898  0.071383
# 24  0.929997  0.053910     0.013365     0.997945   0.325264  0.025674
# 25  0.924454  0.105252     0.062341     0.988361   0.284200  0.102252
# 26  0.917162  0.120216     0.099997     0.977737   0.249790  0.142820
# 27  0.905121  0.115899     0.131280     0.962484   0.205970  0.160354
# 28  0.927034  0.085001     0.039562     0.992821   0.290028  0.069626
# 29  0.912454  0.107828     0.103331     0.972433   0.217440  0.140090
# 30  0.907983  0.130850     0.138718     0.965008   0.227121  0.172239
# 31  0.922041  0.096103     0.064624     0.985600   0.249621  0.102669
# 32  0.916610  0.105409     0.089042     0.977956   0.230432  0.128449
# 33  0.922834  0.093414     0.060085     0.986788   0.252116  0.097043
# 34  0.921370  0.098279     0.068421     0.984597   0.247718  0.107225
# 35  0.928421  0.076567     0.029461     0.995059   0.306515  0.053756
# 36  0.923705  0.097142     0.059595     0.987760   0.265195  0.097320
# 37  0.913877  0.111331     0.102379     0.974032   0.226156  0.140950
# 38  0.920072  0.097650     0.072147     0.982928   0.238536  0.110786
# 39  0.910745  0.110998     0.111092     0.970021   0.215501  0.146608
# 40  0.926563  0.086825     0.042462     0.992099   0.284895  0.073908
# 41  0.898637  0.120378     0.152910     0.953917   0.197410  0.172333
# 42  0.919574  0.091521     0.069093     0.982618   0.227596  0.106005
# 43  0.911590  0.094631     0.093847     0.972207   0.200197  0.127790
# 44  0.916053  0.104271     0.089757     0.977305   0.226708  0.128599
# 45  0.912617  0.105429     0.100698     0.972803   0.215358  0.137229
# 46  0.904038  0.115288     0.133507     0.961156   0.203047  0.161093
# 47  0.919792  0.102758     0.076952     0.982270   0.243419  0.116937
# 48  0.925542  0.080785     0.042784     0.990979   0.260114  0.073481
# 49  0.913622  0.107591     0.099773     0.973951   0.221139  0.137506

# %%
balanced_accuracy = (metrics_df["Sensitivity"].values[49]+metrics_df["Specificity"].values[49])/2
balanced_accuracy
# Out:
# 0.5368620201714843

# %%
x_axis_ticks = np.arange(num_epochs)
y_axis_ticks = np.arange(11)/10

metrics_fig = metrics_df.plot(figsize = (12, 5), use_index = True, title = model_name + " training metrics", 
                              xticks = x_axis_ticks, yticks = y_axis_ticks)

metrics_fig = metrics_fig.legend(bbox_to_anchor=(1, 1))
metrics_fig = metrics_fig.get_figure()

# %%
# Save model
if not os.path.exists('out_model/'):
    os.mkdir('out_model/')

model.save('out_model/' + model_name + ".h5")

# %%
# Save metrics df
if not os.path.exists('out_metrics/'):
    os.mkdir('out_metrics/')

metrics_df.to_csv("out_metrics/training_metrics.csv", index=False)

# %%
model = load_model("out_model/" + model_name + ".h5", custom_objects={"MaskedConv1D": MaskedConv1D})

# %%
metrics_df = pd.read_csv ("out_metrics/training_metrics.csv")
